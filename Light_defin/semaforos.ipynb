# %% [markdown]
# ## Entrenamos el modelo de yolo

# %%
from ultralytics import YOLO
from pathlib import Path

# === RUTA AL ARCHIVO data.yaml ===
root = Path().resolve()
yaml_path = root / "semaforos" / "data.yaml"  # Cambia si el nombre de la carpeta es distinto

# === CARGAR MODELO ===
model = YOLO("yolov8s.pt")  # Modelo más preciso que yolov8n, pero sigue siendo rápido

# === ENTRENAMIENTO ===
model.train(
    data=str(yaml_path),
    epochs=30,                # Aumentamos a 30 para mejorar precisión sin pasar las 5h
    imgsz=416,                # Tamaño estándar (menor que 640 para reducir tiempo)
    batch=16,                 # Mantener moderado para evitar saturar CPU
    name="traffic_light_detector",
    project="runs/train",
    pretrained=True,
    patience=10,              # Parada temprana si no mejora
    val=True                  # Validación en cada época
)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:01<00:00, 14.6MB/s]
# New https://pypi.org/project/ultralytics/8.3.111 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.86 🚀 Python-3.11.5 torch-2.6.0 CPU (Apple M1)
# ...

# %% [markdown]
# ## deteccion de semaforos en imagenes random

# %%
# %matplotlib inline

from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt
from pathlib import Path
import random
import os

# === Cargar el modelo entrenado de semáforos ===
model = YOLO("runs/train/traffic_light_detector/weights/best.pt")

# === Directorio con imágenes de test de semáforos ===
image_dir = Path("semaforos/test/images")

# Comprobar si existe
if not image_dir.exists():
    raise FileNotFoundError(f"No se encontró la carpeta: {image_dir}")

# Obtener una imagen aleatoria
image_list = list(image_dir.glob("*.jpg"))
if not image_list:
    raise FileNotFoundError("No se encontraron imágenes .jpg en el directorio.")

image_path = random.choice(image_list)

# Cargar la imagen
img = cv2.imread(str(image_path))
if img is None:
    raise ValueError(f"No se pudo cargar la imagen: {image_path}")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# === Inferencia ===
results = model(img_rgb, conf=0.3)[0]

# === Dibujar las cajas ===
for box in results.boxes:
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    conf = float(box.conf[0])
    label = model.names[int(box.cls[0])]
    color = (0, 255, 0)
    cv2.rectangle(img_rgb, (x1, y1), (x2, y2), color, 2)
    cv2.putText(img_rgb, f"{label} {conf:.2f}", (x1, y1 - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

# === Mostrar imagen con detecciones ===
plt.figure(figsize=(10, 8))
plt.imshow(img_rgb)
plt.title(f"Detección de semáforos en: {image_path.name}")
plt.axis("off")
plt.show()
# Out:
# 0: 416x416 (no detections), 68.2ms
# Speed: 0.9ms preprocess, 68.2ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 416)

# %%
from ultralytics import YOLO
from pathlib import Path

# === Ruta al archivo YAML ===
root = Path().resolve()
yaml_path = root / "semaforos"/ "data.yaml"

# === Cargar modelo medio para mayor precisión ===
model = YOLO("yolov8m.pt")

# === Entrenamiento intensivo ===
model.train(
    data=str(yaml_path),
    epochs=50,               # más épocas para mejor generalización
    imgsz=640,               # mayor resolución para precisión en detalles pequeños
    batch=8,                 # carga aceptable para CPU M1
    name="traffic_light_detector_high_precision",
    project="runs/train",
    pretrained=True,
    optimizer="AdamW",       # optimizador más eficaz en problemas complejos
    close_mosaic=15,         # evita mezclas en últimas épocas
    patience=20,             # evita detener antes de tiempo
    cos_lr=True,             # scheduler más suave
    amp=True,                # entrenamiento mixto para acelerar con precisión
    workers=8,               # si tu CPU lo aguanta, aprovecha núcleos
    seed=42,                 # para reproducibilidad
    verbose=True             # salida detallada
)
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:03<00:00, 17.0MB/s]
# New https://pypi.org/project/ultralytics/8.3.111 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.86 🚀 Python-3.11.5 torch-2.6.0 CPU (Apple M1)
# ...

# %%
# %matplotlib inline

from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt
from pathlib import Path
import random
import os

# === Cargar el modelo entrenado de semáforos ===
model = YOLO("runs/train/traffic_light_detector_high_precision/weights/best.pt")

# === Directorio con imágenes de test de semáforos ===
image_dir = Path("semaforos/test/images")

# Comprobar si existe
if not image_dir.exists():
    raise FileNotFoundError(f"No se encontró la carpeta: {image_dir}")

# Obtener una imagen aleatoria
image_list = list(image_dir.glob("*.jpg"))
if not image_list:
    raise FileNotFoundError("No se encontraron imágenes .jpg en el directorio.")

image_path = random.choice(image_list)

# Cargar la imagen
img = cv2.imread(str(image_path))
if img is None:
    raise ValueError(f"No se pudo cargar la imagen: {image_path}")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# === Inferencia ===
results = model(img_rgb, conf=0.3)[0]

# === Dibujar las cajas ===
for box in results.boxes:
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    conf = float(box.conf[0])
    label = model.names[int(box.cls[0])]
    color = (0, 255, 0)
    cv2.rectangle(img_rgb, (x1, y1), (x2, y2), color, 2)
    cv2.putText(img_rgb, f"{label} {conf:.2f}", (x1, y1 - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

# === Mostrar imagen con detecciones ===
plt.figure(figsize=(10, 8))
plt.imshow(img_rgb)
plt.title(f"Detección de semáforos en: {image_path.name}")
plt.axis("off")
plt.show()
# Out:
# 0: 640x640 (no detections), 245.9ms
# Speed: 1.6ms preprocess, 245.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
